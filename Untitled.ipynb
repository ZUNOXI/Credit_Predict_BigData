# %% [markdown]
# ## 파이썬 문법 테스트

# %%
print('이름을 입력하세요', end="")
name = input();
print(name)
# Out:
# 이름을 입력하세요이준호
# 이준호

# %%
name1 = int(input("첫번째 숫자를 입력하세요"));
name2 = int(input("두번째 숫자를 입력하세요"));
print(name1+name2)

# %%
sentence = input("문장을 입력하세요").split()
for i in sentence:
     print(i);

# %%
a = int(input())
for i in range(a):
    print("#",end='')
# Out:
# 3
# ###
